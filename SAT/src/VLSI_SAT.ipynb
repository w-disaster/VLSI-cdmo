# %%
from solver.VLSI_SAT import *
from solver.VLSI_SAT_rot import *
from utils.plot_plate import *
from utils.read_instance_write_sol import *
from time import time

# %%
INSTANCES_REL_PATH = "../../instances/"
OUT_FILE_REL_PATH = "../out/"

# %%
def solve_all_instances():
    n_instances = 40
    # All but the last instance
    for i in range(1, n_instances):
        plate = instance_to_plate(INSTANCES_REL_PATH + "ins-" + str(i) + ".txt")
        start_time = time()

        # Solve VLSI
        plate = solver(plate).solve_vlsi()
        print("Instance n. {}".format(i))
        print("Elapsed time: {}, plate dim (w, h) = ({}, {})"
                    .format(time() - start_time, plate.get_dim()[0], 
                        plate.get_dim()[1]))
        plate_to_solution(OUT_FILE_REL_PATH + "ins-" + str(i) + ".txt", plate)
        plot_plate(plate, i)

# %%
#solver = VLSI_SAT
#solve_all_instances()

# %%
solver = VLSI_SAT_rot
solve_all_instances()
# Out:
# Instance n. 1
# Elapsed time: 0.8534789085388184, plate dim (w, h) = (8, 8)
# Instance n. 2
# Elapsed time: 0.6869211196899414, plate dim (w, h) = (9, 8)
# Instance n. 3
# Elapsed time: 1.141986608505249, plate dim (w, h) = (10, 10)
# Instance n. 4
# Elapsed time: 3.4288575649261475, plate dim (w, h) = (11, 11)
# Instance n. 5
# Elapsed time: 4.235005617141724, plate dim (w, h) = (12, 12)
# Instance n. 6
# Elapsed time: 8.137422800064087, plate dim (w, h) = (13, 13)
# Instance n. 7
# Elapsed time: 6.790677785873413, plate dim (w, h) = (14, 14)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_23934/3633353645.py in <module>
#       1 solver = VLSI_SAT_rot
# ----> 2 solve_all_instances()
#
# /tmp/ipykernel_23934/2245343252.py in solve_all_instances()
#       7
#       8         # Solve VLSI
# ----> 9         plate = solver(plate).solve_vlsi()
#      10         print("Instance n. {}".format(i))
#      11         print("Elapsed time: {}, plate dim (w, h) = ({}, {})"
#
# ~/Desktop/uni/ai/lecture_notes/comb_opt/fabri_morgese/SAT/src/solver/VLSI_SAT_rot.py in solve_vlsi(self)
#     176
#     177         # Order encoding
# --> 178         (self.px, self.py, self.ph, self.z) = self.order_encode_variables(self.s, self.csw,
#     179                 self.csh, self.w, self.n, self.h_min, self.h_max)
#     180
#
# ~/Desktop/uni/ai/lecture_notes/comb_opt/fabri_morgese/SAT/src/solver/VLSI_SAT_rot.py in order_encode_variables(self, s, csw, csh, w, n, h_min, h_max)
#      47
#      48         for h in range(h_min, h_max):
# ---> 49             s.add([Or(Not(ph[h - h_min]),
#      50                 Or([py[k][i] for i in range(h - csh[k] + 1)])) for k in range(n)])
#      51
#
# ~/Desktop/uni/ai/lecture_notes/comb_opt/fabri_morgese/SAT/src/solver/VLSI_SAT_rot.py in <listcomp>(.0)
#      48         for h in range(h_min, h_max):
#      49             s.add([Or(Not(ph[h - h_min]),
# ---> 50                 Or([py[k][i] for i in range(h - csh[k] + 1)])) for k in range(n)])
#      51
#      52             hc = And([If(z[k], And([py[k][i] for i in range(h - csh[k], h_max)]),
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in Or(*args)
#    1893         return _probe_or(args, ctx)
#    1894     else:
# -> 1895         args = _coerce_expr_list(args, ctx)
#    1896         _args, sz = _to_ast_array(args)
#    1897         return BoolRef(Z3_mk_or(ctx.ref(), sz, _args), ctx)
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in _coerce_expr_list(alist, ctx)
#    1225     if not has_expr:
#    1226         alist = [_py2expr(a, ctx) for a in alist]
# -> 1227     s = _reduce(_coerce_expr_merge, alist, None)
#    1228     return [s.cast(a) for a in alist]
#    1229
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in _reduce(func, sequence, initial)
#    1213     result = initial
#    1214     for element in sequence:
# -> 1215         result = func(result, element)
#    1216     return result
#    1217
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in _coerce_expr_merge(s, a)
#    1180         if s is None:
#    1181             return s1
# -> 1182         if s1.eq(s):
#    1183             return s
#    1184         elif s.subsort(s1):
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in eq(self, other)
#     411         if z3_debug():
#     412             _z3_assert(is_ast(other), "Z3 AST expected")
# --> 413         return Z3_is_eq_ast(self.ctx_ref(), self.as_ast(), other.as_ast())
#     414
#     415     def translate(self, target):
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in as_ast(self)
#     555
#     556     def as_ast(self):
# --> 557         return Z3_sort_to_ast(self.ctx_ref(), self.ast)
#     558
#     559     def get_id(self):
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in ctx_ref(self)
#     394     def ctx_ref(self):
#     395         """Return a reference to the C context where this AST node is stored."""
# --> 396         return self.ctx.ref()
#     397
#     398     def eq(self, other):
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in ref(self)
#     216     def ref(self):
#     217         """Return a reference to the actual C pointer to the Z3 context."""
# --> 218         return self.ctx
#     219
#     220     def interrupt(self):
#
# KeyboardInterrupt:
