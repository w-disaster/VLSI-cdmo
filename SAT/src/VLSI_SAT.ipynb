# %%
from solver.VLSI_SAT import *
from solver.VLSI_SAT_rot import *
from utils.plot_plate import *
from utils.read_instance_write_sol import *
from time import time

# %%
def solve_all_instances(solver):
    n_instances = 40
    # All but the last instance
    for i in range(1, n_instances):
        plate = instance_to_plate("../../instances/ins-" + str(i) + ".txt")
        start_time = time()

        # Solve VLSI
        plate = solver.solve_vlsi(plate)
        
        print("Instance n. {}".format(i))
        print("Elapsed time: {}, plate dim (w, h) = ({}, {})"
                    .format(time() - start_time, plate.get_dim()[0], 
                        plate.get_dim()[1]))
        plot_plate(plate)

# %%
solve_all_instances(VLSI_SAT_rot())
# Out:
# no overlap c
# largest rect
# breaking sym
# Evaluate step
# SAT, h: 8
# [False, True, True, False]
# Instance n. 1
# Elapsed time: 0.20241117477416992, plate dim (w, h) = (8, 8)
# no overlap c
# largest rect
# breaking sym
# Evaluate step
# SAT, h: 8
# [False, True, True, False, True]
# Instance n. 2
# Elapsed time: 0.4183013439178467, plate dim (w, h) = (9, 8)
# no overlap c
# largest rect
# breaking sym
# Evaluate step
# SAT, h: 10
# [False, True, False, True, False, True]
# Instance n. 3
# Elapsed time: 0.6741323471069336, plate dim (w, h) = (10, 10)
# no overlap c
# largest rect
# breaking sym
# Evaluate step
# SAT, h: 11
# [False, False, True, True, True, False, False]
# Instance n. 4
# Elapsed time: 1.145564317703247, plate dim (w, h) = (11, 11)
# no overlap c
# largest rect
# breaking sym
# Evaluate step
# SAT, h: 12
# [False, True, True, True, True, True, True, False]
# Instance n. 5
# Elapsed time: 1.8346786499023438, plate dim (w, h) = (12, 12)
# no overlap c
# largest rect
# breaking sym
# Evaluate step
# SAT, h: 13
# [False, True, True, True, False, True, False, False, True]
# Instance n. 6
# Elapsed time: 2.2396697998046875, plate dim (w, h) = (13, 13)
# no overlap c
# largest rect
# breaking sym
# Evaluate step
# SAT, h: 14
# [False, True, True, True, True, True, True, True, True]
# Instance n. 7
# Elapsed time: 2.992594003677368, plate dim (w, h) = (14, 14)
# no overlap c
# largest rect
# breaking sym
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# /tmp/ipykernel_104884/2235749589.py in <module>
# ----> 1 solve_all_instances(VLSI_SAT_rot())
#
# /tmp/ipykernel_104884/1264504305.py in solve_all_instances(solver)
#       7
#       8         # Solve VLSI
# ----> 9         plate = solver.solve_vlsi(plate)
#      10
#      11         print("Instance n. {}".format(i))
#
# ~/Desktop/uni/ai/lecture_notes/comb_opt/VLSI-cdmo/SAT/src/solver/VLSI_SAT_rot.py in solve_vlsi(self, plate)
#     257                 Or([py[k][i] for i in range(h - csh[k] + 1)])) for k in range(n)])
#     258
# --> 259             hc = And([If(z[k], And([py[k][i] for i in range(h - csh[k], h_max)]),
#     260                 And([py[k][i] for i in range(h - csw[k], h_max)])) for k in range(n)])
#     261             s.add(Implies(ph[h - h_min], hc))
#
# ~/Desktop/uni/ai/lecture_notes/comb_opt/VLSI-cdmo/SAT/src/solver/VLSI_SAT_rot.py in <listcomp>(.0)
#     258
#     259             hc = And([If(z[k], And([py[k][i] for i in range(h - csh[k], h_max)]),
# --> 260                 And([py[k][i] for i in range(h - csw[k], h_max)])) for k in range(n)])
#     261             s.add(Implies(ph[h - h_min], hc))
#     262
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in And(*args)
#    1860         return _probe_and(args, ctx)
#    1861     else:
# -> 1862         args = _coerce_expr_list(args, ctx)
#    1863         _args, sz = _to_ast_array(args)
#    1864         return BoolRef(Z3_mk_and(ctx.ref(), sz, _args), ctx)
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in _coerce_expr_list(alist, ctx)
#    1225     if not has_expr:
#    1226         alist = [_py2expr(a, ctx) for a in alist]
# -> 1227     s = _reduce(_coerce_expr_merge, alist, None)
#    1228     return [s.cast(a) for a in alist]
#    1229
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in _reduce(func, sequence, initial)
#    1213     result = initial
#    1214     for element in sequence:
# -> 1215         result = func(result, element)
#    1216     return result
#    1217
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in _coerce_expr_merge(s, a)
#    1177 def _coerce_expr_merge(s, a):
#    1178     if is_expr(a):
# -> 1179         s1 = a.sort()
#    1180         if s is None:
#    1181             return s1
#
# ~/.local/lib/python3.8/site-packages/z3/z3.py in sort(self)
#    1539
#    1540     def sort(self):
# -> 1541         return BoolSortRef(Z3_get_sort(self.ctx_ref(), self.as_ast()), self.ctx)
#    1542
#    1543     def __rmul__(self, other):
#
# ~/.local/lib/python3.8/site-packages/z3/z3core.py in Z3_get_sort(a0, a1, _elems)
#    2948 def Z3_get_sort(a0, a1, _elems=Elementaries(_lib.Z3_get_sort)):
#    2949   r = _elems.f(a0, a1)
# -> 2950   _elems.Check(a0)
#    2951   return r
#    2952
#
# ~/.local/lib/python3.8/site-packages/z3/z3core.py in Check(self, ctx)
#    1455
#    1456   def Check(self, ctx):
# -> 1457     err = self.get_error_code(ctx)
#    1458     if err != self.OK:
#    1459         raise self.Exception(self.get_error_message(ctx, err))
#
# ArgumentError: argument 1: <class 'KeyboardInterrupt'>:
